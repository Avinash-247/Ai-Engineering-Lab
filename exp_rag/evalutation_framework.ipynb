# %%
from deepeval.test_case import LLMTestCase

test_case=LLMTestCase(
    input="what is the captial of france?",
    actual_output="paris",
    expected_output="paris",
    context=["France is an Europe"],
)

test_case=LLMTestCase(
    input="What is the capital of France?",
    actual_output="Paris",
)

# %% [markdown]
# martices

# %%
from deepeval.metrics import AnswerRelevancyMetric

matric=AnswerRelevancyMetric()
# Out:
# ---------------------------------------------------------------------------
# DeepEvalError                             Traceback (most recent call last)
# Cell In[5], line 3
#       1 from deepeval.metrics import AnswerRelevancyMetric
#       2
# ----> 3 matric=AnswerRelevancyMetric(model=None)
#
# File c:\Users\vempa\learnning_rag\exp_rag\.venv\Lib\site-packages\deepeval\metrics\answer_relevancy\answer_relevancy.py:42, in AnswerRelevancyMetric.__init__(self, threshold, model, include_reason, async_mode, strict_mode, verbose_mode)
#      32 def __init__(
#      33     self,
#      34     threshold: float = 0.5,
#    (...)     39     verbose_mode: bool = False,
#      40 ):
#      41     self.threshold = 1 if strict_mode else threshold
# ---> 42     self.model, self.using_native_model = initialize_model(model)
#      43     self.evaluation_model = self.model.get_model_name()
#      44     self.include_reason = include_reason
#
# File c:\Users\vempa\learnning_rag\exp_rag\.venv\Lib\site-packages\deepeval\metrics\utils.py:698, in initialize_model(model)
#     696     return AmazonBedrockModel(model=model), True
#     697 elif isinstance(model, str) or model is None:
# --> 698     return GPTModel(model=model), True
#     700 # Otherwise (the model is a wrong type), we raise an error
#     701 raise TypeError(
#     702     f"Unsupported type for model: {type(model)}. Expected None, str, DeepEvalBaseLLM, GPTModel, AzureOpenAIModel, LiteLLMModel, OllamaModel, LocalModel."
#     703 )
#
# File c:\Users\vempa\learnning_rag\exp_rag\.venv\Lib\site-packages\deepeval\models\llms\openai_model.py:142, in GPTModel.__init__(self, model, api_key, base_url, temperature, cost_per_input_token, cost_per_output_token, generation_kwargs, **kwargs)
#     139 self.generation_kwargs = dict(generation_kwargs or {})
#     140 self.generation_kwargs.pop("temperature", None)
# --> 142 super().__init__(model)
#
# File c:\Users\vempa\learnning_rag\exp_rag\.venv\Lib\site-packages\deepeval\models\base_model.py:49, in DeepEvalBaseLLM.__init__(self, model, *args, **kwargs)
#      47 def __init__(self, model: Optional[str] = None, *args, **kwargs):
#      48     self.name = parse_model_name(model)
# ---> 49     self.model = self.load_model()
#
# File c:\Users\vempa\learnning_rag\exp_rag\.venv\Lib\site-packages\deepeval\models\llms\openai_model.py:471, in GPTModel.load_model(self, async_mode)
#     469 def load_model(self, async_mode: bool = False):
#     470     if not async_mode:
# --> 471         return self._build_client(OpenAI)
#     472     return self._build_client(AsyncOpenAI)
#
# File c:\Users\vempa\learnning_rag\exp_rag\.venv\Lib\site-packages\deepeval\models\llms\openai_model.py:489, in GPTModel._build_client(self, cls)
#     488 def _build_client(self, cls):
# --> 489     api_key = require_secret_api_key(
#     490         self.api_key,
#     491         provider_label="OpenAI",
#     492         env_var_name="OPENAI_API_KEY",
#     493         param_hint="`api_key` to GPTModel(...)",
#     494     )
#     496     kw = dict(
#     497         api_key=api_key,
#     498         base_url=self.base_url,
#     499         **self._client_kwargs(),
#     500     )
#     502     # Support separate sync/async HTTP clients (#2351).
#     503     # OpenAI expects httpx.Client; AsyncOpenAI expects httpx.AsyncClient.
#     504     # Passing the wrong type raises TypeError, so we handle them separately.
#
# File c:\Users\vempa\learnning_rag\exp_rag\.venv\Lib\site-packages\deepeval\models\utils.py:100, in require_secret_api_key(secret, provider_label, env_var_name, param_hint)
#      80 """
#      81 Normalize and validate a provider API key stored as a SecretStr.
#      82
#    (...)     97     DeepEvalError: if the key is missing or empty.
#      98 """
#      99 if secret is None:
# --> 100     raise DeepEvalError(
#     101         f"{provider_label} API key is not configured. "
#     102         f"Set {env_var_name} in your environment or pass "
#     103         f"{param_hint}."
#     104     )
#     106 api_key = secret.get_secret_value()
#     107 if not api_key:
#
# DeepEvalError: OpenAI API key is not configured. Set OPENAI_API_KEY in your environment or pass `api_key` to GPTModel(...).

# %%
from deepeval import evaluate

evaluate(
    test_case=[test_case],
    matric=[matric]
)
