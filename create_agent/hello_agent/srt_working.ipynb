# %%
from respose_agent  import replay
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.

# %%
replay()
# Out:
# ('content',
#  [{'type': 'text',
#    'text': 'Hello Avi! \n\n* The capital of India is **New Delhi**.\n* Your name is **Avi** (you just told me!). \n\nHow can I help you today?',
#    'extras': {'signature': 'El4KXAERTTIPHYExEirRmVpuLXJqvbOurB6u5/oMOrQewHKoSZizsuPJZvzvOiiUeKTVLFRsHgcoghCRibbaEGSvjSUxBZrrNkCXYGQSBL7qxjRbl46Q0j+9sKNPyuFx'}}])
