# %%
x=5

# %%
x
# Out:
# 5

# %%
from langchain.chat_models import init_chat_model

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model=init_chat_model(model="google_genai:gemini-3.5-flash-lite")

# %%
from langchain.agents import create_agent

# %%
agent=create_agent(
    model=model
)

# %%
response=agent.invoke({
    "messages":[f"this is me"]
    })

# %%
print(response)
# Out:
# {'messages': [HumanMessage(content='this is me', additional_kwargs={}, response_metadata={}, id='aa49e945-d95a-4c6d-8d26-db73c12d9c22'), AIMessage(content=[{'type': 'text', 'text': 'Nice to meet you! How can I help you today?', 'extras': {'signature': 'El4KXAERTTIPIiFx+6tomi1d/iUQRlxFwppSYmgChajyeFQp8+v3U4dQmhDrkQapFG09ctKKFJqLRGe9Xy8aERQCqe8sAE7yC30k8RTzMykQ8PYh8t9r1WyGc/NfJ9oB'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a08b0d-15d4-7b73-9c65-c8b138ba6e18-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4, 'output_tokens': 12, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}})]}
